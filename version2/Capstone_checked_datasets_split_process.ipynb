# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pydicom
# Out:
# Collecting pydicom
#   Downloading pydicom-3.0.1-py3-none-any.whl.metadata (9.4 kB)
# Downloading pydicom-3.0.1-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 62.8 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-3.0.1

# %%
import os
import pydicom
import hashlib
from PIL import Image
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
from collections import defaultdict
from sklearn.model_selection import train_test_split
import seaborn as sns

# %% [markdown]
# # Analyze datasets

# %%
pano_path = "/content/drive/MyDrive/capstone_periodontal/data_all_fin/pano"
peri_path = "/content/drive/MyDrive/capstone_periodontal/data_all_fin/peri"
datasets_csv_path = "/content/drive/MyDrive/capstone_periodontal/data_all_fin/csv_folder/combined_metadata_boneloss_checked.csv"

# %%
pano_count = sum(1 for file in os.listdir(pano_path) if file.endswith(".jpg"))
peri_count = sum(1 for file in os.listdir(peri_path) if file.endswith(".jpg"))

print(pano_count)
print(peri_count)
# Out:
# 189
# 146

# %%
datasets_df = pd.read_csv(datasets_csv_path)
display(datasets_df)
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 img_type                 id  \
# 0               0             0           0     pano   5613828_020422_0
# 1               1             0           0     pano   5613828_020422_0
# 2               2             1           1     pano   5917597_052724_0
# 3               3             1           1     pano   5917597_052724_0
# 4               4             2           2     pano   5419656_102821_2
# ..            ...           ...         ...      ...                ...
# 744           744           338         338     peri  5420736_081922_39
# 745           745           339         339     peri  5420736_100319_16
# 746           746           340         340     peri  5420736_111921_32
# 747           747           341         341     peri   5420736_061917_7
# 748           748           341         341     peri   5420736_061917_7
#
#                  txt_fname               Filename Specific Character Set  \
# 0     5613828_020422_0.txt   5613828_020422_0.dcm             ISO_IR 100
# 1     5613828_020422_0.txt   5613828_020422_0.dcm             ISO_IR 100
# 2     5917597_052724_0.txt   5917597_052724_0.dcm             ISO_IR 100
# 3     5917597_052724_0.txt   5917597_052724_0.dcm             ISO_IR 100
# 4     5419656_102821_2.txt   5419656_102821_2.dcm             ISO_IR 100
# ..                     ...                    ...                    ...
# 744  5420736_081922_39.txt  5420736_081922_39.dcm             ISO_IR 100
# 745  5420736_100319_16.txt  5420736_100319_16.dcm             ISO_IR 100
# 746  5420736_111921_32.txt  5420736_111921_32.dcm             ISO_IR 100
# 747   5420736_061917_7.txt   5420736_061917_7.dcm             ISO_IR 100
# 748   5420736_061917_7.txt   5420736_061917_7.dcm             ISO_IR 100
#
#                   Image Type  Instance Creation Date  ...  \
# 0                   ORIGINAL              20250320.0  ...
# 1                   ORIGINAL              20250320.0  ...
# 2                   ORIGINAL              20250320.0  ...
# 3                   ORIGINAL              20250320.0  ...
# 4                   ORIGINAL              20250320.0  ...
# ..                       ...                     ...  ...
# 744  ['ORIGINAL', 'PRIMARY']                     NaN  ...
# 745  ['ORIGINAL', 'PRIMARY']                     NaN  ...
# 746  ['ORIGINAL', 'PRIMARY']                     NaN  ...
# 747  ['ORIGINAL', 'PRIMARY']                     NaN  ...
# 748  ['ORIGINAL', 'PRIMARY']                     NaN  ...
#
#      Field of View Rotation Field of View Horizontal Flip  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN
# ..                      ...                           ...
# 744                     NaN                           NaN
# 745                     NaN                           NaN
# 746                     NaN                           NaN
# 747                     0.0                            NO
# 748                     0.0                            NO
#
#               img_filename  Spatial Resolution  \
# 0     5613828_020422_0.jpg                 NaN
# 1     5613828_020422_0.jpg                 NaN
# 2     5917597_052724_0.jpg                 NaN
# 3     5917597_052724_0.jpg                 NaN
# 4     5419656_102821_2.jpg                 NaN
# ..                     ...                 ...
# 744  5420736_081922_39.jpg                 NaN
# 745  5420736_100319_16.jpg                 NaN
# 746  5420736_111921_32.jpg                 NaN
# 747   5420736_061917_7.jpg                 NaN
# 748   5420736_061917_7.jpg                 NaN
#
#      Acquisition Device Processing Code  X-Ray Tube Current in uA  \
# 0                                   NaN                       NaN
# 1                                   NaN                       NaN
# 2                                   NaN                       NaN
# 3                                   NaN                       NaN
# 4                                   NaN                       NaN
# ..                                  ...                       ...
# 744                                 NaN                       NaN
# 745                                 NaN                       NaN
# 746                                 NaN                       NaN
# 747                                 NaN                       NaN
# 748                                 NaN                       NaN
#
#      Patient's Age Object Sequence Bone Loss % boneloss_class
# 0              NaN               1        0.29              1
# 1              NaN               2        0.27              1
# 2              NaN               1        3.97              1
# 3              NaN               2       13.44              1
# 4              NaN               1        0.37              1
# ..             ...             ...         ...            ...
# 744            NaN               2       16.06              2
# 745            NaN               1       21.99              2
# 746            NaN               1        4.48              1
# 747            NaN               1       20.07              2
# 748            NaN               2        0.30              1
#
# [749 rows x 124 columns]

# %%
total_files = datasets_df['Filename'].nunique()
print(total_files)
# Out:
# 335

# %%
unique_class = datasets_df['boneloss_class'].nunique()
print(unique_class)
# Out:
# 4

# %% [markdown]
# ## Check duplicate

# %%
def hash_image(image_path):
    """Generate a hash for an image file."""
    with Image.open(image_path) as img:
        img = img.convert('RGB')  # Ensure consistent format
        resized = img.resize((100, 100))  # Resize for consistency and speed
        img_bytes = resized.tobytes()
        return hashlib.md5(img_bytes).hexdigest()

def find_duplicate_images(folder_path):
    """Check for duplicate images in a folder and print them."""
    hashes = {}
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        if os.path.isfile(file_path) and filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            try:
                img_hash = hash_image(file_path)
                if img_hash in hashes:
                    print(f"Duplicate found:\n  {file_path}\n  {hashes[img_hash]}\n")
                else:
                    hashes[img_hash] = file_path
            except Exception as e:
                print(f"Error processing {file_path}: {e}")

# %%
find_duplicate_images(pano_path)

# %%
find_duplicate_images(peri_path)

# %% [markdown]
# ## Concern
# 1. same HN must be in only train or test
# 3. number of implant should be around the same ratio as config train : val : test = 80 : 10 : 10
# 4. train, val, and test must have at least 1 implant in every levels

# %% [markdown]
# ### Distribution of Pano + Peri

# %%
# Group by "Patient ID" and aggregate the counts
uniqueHN_df = datasets_df.groupby("Patient ID").agg(
    pano_count = ("img_type", lambda x: np.sum(x == "pano")),
    peri_count = ("img_type", lambda x: np.sum(x == "peri")),
    implant_count = ("img_type", "count"),
    level1 = ("boneloss_class", lambda x: np.sum(x == 1)),
    level2 = ("boneloss_class", lambda x: np.sum(x == 2)),
    level3 = ("boneloss_class", lambda x: np.sum(x == 3)),
    level4 = ("boneloss_class", lambda x: np.sum(x == 4))
).reset_index()
uniqueHN_df = uniqueHN_df.rename(columns={"Patient ID": "uniqueHN"})
uniqueHN_df["uniqueHN"] = uniqueHN_df["uniqueHN"].str.replace("-", "", regex=False)

# %%
display(uniqueHN_df)
# Out:
#     uniqueHN  pano_count  peri_count  implant_count  level1  level2  level3  \
# 0    4112969           2           0              2       1       1       0
# 1    4113591           2           0              2       1       1       0
# 2    4113618          14           0             14      14       0       0
# 3     417543           3           0              3       0       3       0
# 4    4213295           2           0              2       2       0       0
# ..       ...         ...         ...            ...     ...     ...     ...
# 96    655212           1           0              1       1       0       0
# 97    659796           1           0              1       1       0       0
# 98   6610915           2           5              7       6       1       0
# 99    669050           3           0              3       3       0       0
# 100    67519           2           0              2       2       0       0
#
#      level4
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 96        0
# 97        0
# 98        0
# 99        0
# 100       0
#
# [101 rows x 8 columns]

# %%
# Set up the figure
plt.figure(figsize=(12, 6))

# Melt the dataframe for seaborn
melted_df = uniqueHN_df.melt(id_vars="uniqueHN", value_vars=["pano_count", "peri_count", "implant_count"],
                             var_name="Image Type", value_name="Count")

# Plot
sns.boxplot(x="Image Type", y="Count", data=melted_df)
sns.stripplot(x="Image Type", y="Count", data=melted_df, color="black", alpha=0.3, jitter=0.2)
plt.title("Distribution of image types per patient")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(uniqueHN_df["implant_count"], bins=20, kde=True)
plt.title("Distribution of Implant Image Counts per Patient")
plt.xlabel("Implant Count")
plt.ylabel("Number of Patients")
plt.show()

# %%
# Create a new dataframe for stacked bar plot
bone_levels_df = uniqueHN_df[["uniqueHN", "level1", "level2", "level3", "level4"]].set_index("uniqueHN")

# Plot
bone_levels_df.plot(kind="bar", stacked=True, figsize=(14, 6), colormap="viridis")
plt.title("Bone Loss Levels per Patient")
plt.xlabel("Patient ID")
plt.ylabel("Number of Instances")
plt.legend(title="Bone Loss Level")
plt.tight_layout()
plt.show()

# %%
level_sums = bone_levels_df[["level1", "level2", "level3", "level4"]].sum()
print(level_sums)
# Out:
# level1    619
# level2     75
# level3     34
# level4     21
# dtype: int64

# %%
def count_patients_with_level(uniqueHN_df, level):
    if level not in [1, 2, 3, 4]:
        raise ValueError("Level must be an integer between 1 and 4.")

    col_name = f"level{level}"
    return (uniqueHN_df[col_name] > 0).sum()

# %%
num_with_level1 = count_patients_with_level(uniqueHN_df, 1)
print(f"Number of patients with bone loss level 1: {num_with_level1}")

num_with_level2 = count_patients_with_level(uniqueHN_df, 2)
print(f"Number of patients with bone loss level 2: {num_with_level2}")

num_with_level3 = count_patients_with_level(uniqueHN_df, 3)
print(f"Number of patients with bone loss level 3: {num_with_level3}")

num_with_level4 = count_patients_with_level(uniqueHN_df, 4)
print(f"Number of patients with bone loss level 4: {num_with_level4}")
# Out:
# Number of patients with bone loss level 1: 97
# Number of patients with bone loss level 2: 31
# Number of patients with bone loss level 3: 10
# Number of patients with bone loss level 4: 6

# %% [markdown]
# ### Distribution of Pano

# %%
pano_df = datasets_df[datasets_df["img_type"] == "pano"]

uniqueHN_pano_df = pano_df.groupby("Patient ID").agg(
    pano_count=("img_type", "count"),
    level1=("boneloss_class", lambda x: np.sum(x == 1)),
    level2=("boneloss_class", lambda x: np.sum(x == 2)),
    level3=("boneloss_class", lambda x: np.sum(x == 3)),
    level4=("boneloss_class", lambda x: np.sum(x == 4))
).reset_index()

uniqueHN_pano_df = uniqueHN_pano_df.rename(columns={"Patient ID": "uniqueHN"})
uniqueHN_pano_df["uniqueHN"] = uniqueHN_pano_df["uniqueHN"].str.replace("-", "", regex=False)

# %%
display(uniqueHN_pano_df)
# Out:
#    uniqueHN  pano_count  level1  level2  level3  level4
# 0   4112969           2       1       1       0       0
# 1   4113591           2       1       1       0       0
# 2   4113618          14      14       0       0       0
# 3    417543           3       0       3       0       0
# 4   4213295           2       2       0       0       0
# ..      ...         ...     ...     ...     ...     ...
# 94   655212           1       1       0       0       0
# 95   659796           1       1       0       0       0
# 96  6610915           2       2       0       0       0
# 97   669050           3       3       0       0       0
# 98    67519           2       2       0       0       0
#
# [99 rows x 6 columns]

# %%
plt.figure(figsize=(8, 4))
sns.histplot(uniqueHN_pano_df["pano_count"], bins=20, kde=True)
plt.title("Distribution of Implant Image Counts per Patient (Panoramic)")
plt.xlabel("Implant Count")
plt.ylabel("Number of Patients")
plt.show()

# %%
# Create a new dataframe for stacked bar plot
pano_bone_levels_df = uniqueHN_pano_df[["uniqueHN", "level1", "level2", "level3", "level4"]].set_index("uniqueHN")

# Plot
pano_bone_levels_df.plot(kind="bar", stacked=True, figsize=(14, 6), colormap="viridis")
plt.title("Bone Loss Levels per Patient (Panoramic)")
plt.xlabel("Patient ID")
plt.ylabel("Number of Instances")
plt.legend(title="Bone Loss Level")
plt.tight_layout()
plt.show()

# %%
level_sums = pano_bone_levels_df[["level1", "level2", "level3", "level4"]].sum()
print(level_sums)
# Out:
# level1    486
# level2     42
# level3      7
# level4      3
# dtype: int64

# %% [markdown]
# ### Distribution of Peri

# %%
peri_df = datasets_df[datasets_df["img_type"] == "peri"]

uniqueHN_peri_df = peri_df.groupby("Patient ID").agg(
    peri_count=("img_type", "count"),
    level1=("boneloss_class", lambda x: np.sum(x == 1)),
    level2=("boneloss_class", lambda x: np.sum(x == 2)),
    level3=("boneloss_class", lambda x: np.sum(x == 3)),
    level4=("boneloss_class", lambda x: np.sum(x == 4))
).reset_index()

uniqueHN_peri_df = uniqueHN_peri_df.rename(columns={"Patient ID": "uniqueHN"})
uniqueHN_peri_df["uniqueHN"] = uniqueHN_peri_df["uniqueHN"].str.replace("-", "", regex=False)

# %%
display(uniqueHN_peri_df)
# Out:
#   uniqueHN  peri_count  level1  level2  level3  level4
# 0   505547           7       3       1       2       1
# 1  5111748           5       0       0       4       1
# 2  5318878          65      41       1      15       8
# 3   534829          46      28      14       3       1
# 4  5420736          68      51      14       3       0
# 5  5521865           7       6       1       0       0
# 6    62199           1       0       1       0       0
# 7   648550           7       0       0       0       7
# 8  6610915           5       4       1       0       0

# %%
plt.figure(figsize=(8, 4))
sns.histplot(uniqueHN_df["peri_count"], bins=20, kde=True)
plt.title("Distribution of Implant Image Counts per Patient (Periapical)")
plt.xlabel("Implant Count")
plt.ylabel("Number of Patients")
plt.show()

# %%
# Create a new dataframe for stacked bar plot
peri_bone_levels_df = uniqueHN_peri_df[["uniqueHN", "level1", "level2", "level3", "level4"]].set_index("uniqueHN")

# Plot
peri_bone_levels_df.plot(kind="bar", stacked=True, figsize=(14, 6), colormap="viridis")
plt.title("Bone Loss Levels per Patient (Periapical)")
plt.xlabel("Patient ID")
plt.ylabel("Number of Instances")
plt.legend(title="Bone Loss Level")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Split the Datasets

# %%
def split_by_implant_image_count(bone_levels_df, ratios=(0.8, 0.1, 0.1), random_state=40):
    """
    Split uniqueHN into train/val/test:
    - Ensure 1 patient with level 4,3,2,1 in each split
    - Remaining patients split based on implant image count (ratio)

    Parameters:
        bone_levels_df (pd.DataFrame): index=uniqueHN, columns=level1~level4
        ratios (tuple): (train_ratio, val_ratio, test_ratio)
        random_state (int): seed

    Returns:
        train_HNs, val_HNs, test_HNs: lists of uniqueHN
    """
    assert np.isclose(sum(ratios), 1.0), "Ratios must sum to 1.0"
    np.random.seed(random_state)

    df = bone_levels_df.copy()
    df["implant_count"] = df[["level1", "level2", "level3", "level4"]].sum(axis=1)

    # Shuffle initially
    df = df.sample(frac=1, random_state=random_state)

    train_HNs, val_HNs, test_HNs = [], [], []
    train_count = val_count = test_count = 0
    assigned_HNs = set()

    def assign_level_to_splits(level_col):
        nonlocal train_count, val_count, test_count
        candidates = df[df[level_col] > 0]
        available = candidates[~candidates.index.isin(assigned_HNs)]

        if len(available) >= 3:
            selected = available.iloc[:3]
        else:
            selected = available

        for i, (hn, row) in enumerate(selected.iterrows()):
            count = row["implant_count"]
            if i == 0:
                train_HNs.append(hn)
                train_count += count
            elif i == 1:
                val_HNs.append(hn)
                val_count += count
            elif i == 2:
                test_HNs.append(hn)
                test_count += count
            assigned_HNs.add(hn)

    # First assign a petients to all level to train/val/test
    assign_level_to_splits("level4")
    assign_level_to_splits("level3")
    # assign_level_to_splits("level2")
    # assign_level_to_splits("level1")


    # Remove already assigned HNs
    remaining_df = df[~df.index.isin(assigned_HNs)]

    # Target implant image counts
    total_implants = df["implant_count"].sum()
    target_train = ratios[0] * total_implants
    target_val = ratios[1] * total_implants
    target_test = ratios[2] * total_implants

    # Assign remaining patients based on implant count
    for hn, row in remaining_df.iterrows():
        count = row["implant_count"]
        if train_count + count <= target_train:
            train_HNs.append(hn)
            train_count += count
        elif val_count + count <= target_val:
            val_HNs.append(hn)
            val_count += count
        else:
            test_HNs.append(hn)
            test_count += count

    return train_HNs, val_HNs, test_HNs

# %%
def split_by_implant_image_count_pano_peri(bone_levels_df, hn_test, ratios=(0.8, 0.2), random_state=40):
    """
    Split uniqueHN into train/val:
    - Ensure 1 patient with level 4,3,2,1 in each split
    - Remaining patients split based on implant image count (ratio)

    Parameters:
        bone_levels_df (pd.DataFrame): index=uniqueHN, columns=level1~level4
        ratios (tuple): (train_ratio, val_ratio, test_ratio)
        random_state (int): seed

    Returns:
        train_HNs, val_HNs: lists of uniqueHN
    """
    assert np.isclose(sum(ratios), 1.0), "Ratios must sum to 1.0"
    np.random.seed(random_state)

    df = bone_levels_df.copy()
    df["implant_count"] = df[["level1", "level2", "level3", "level4"]].sum(axis=1)

    # Shuffle initially
    df = df.sample(frac=1, random_state=random_state)

    train_HNs, val_HNs = [], []
    train_count = val_count = 0
    assigned_HNs = set()

    def assign_level_to_splits(level_col):
        nonlocal train_count, val_count
        candidates = df[df[level_col] > 0]
        available = candidates[~candidates["uniqueHN"].isin(assigned_HNs)]

        if len(available) >= 3:
            selected = available.iloc[:3]
        else:
            selected = available

        for i, row in selected.iterrows():
            hn = row["uniqueHN"]
            count = row["implant_count"]
            if i % 3 == 0:
                train_HNs.append(hn)
                train_count += count
            elif i % 3 == 1:
                val_HNs.append(hn)
                val_count += count

            assigned_HNs.add(hn)

    # First assign a petients to all level to train/val
    assign_level_to_splits("level4")
    assign_level_to_splits("level3")
    # assign_level_to_splits("level2")
    # assign_level_to_splits("level1")


    # Remove already assigned HNs
    remaining_df = df[~df["uniqueHN"].isin(assigned_HNs)]

    # Target implant image counts
    total_implants = df["implant_count"].sum()
    target_train = ratios[0] * total_implants
    target_val = ratios[1] * total_implants

    # Assign remaining patients based on implant count
    for _, row in remaining_df.iterrows():
        hn = row["uniqueHN"]
        count = row["implant_count"]
        if train_count + count <= target_train:
            train_HNs.append(hn)
            train_count += count
        else:
            val_HNs.append(hn)
            val_count += count

    return train_HNs, val_HNs

# %%
def print_level_counts(df, split_HNs, name=""):
    subset = df.loc[split_HNs]
    level_sums = subset[["level1", "level2", "level3", "level4"]].sum()
    print(f"\n{name} Split — {len(split_HNs)} Patients")
    print(level_sums)
    print(f"Total implants: {level_sums.sum()}")

# %%
def save_list_to_txt(data_list, filename):
    with open(filename, 'w') as f:
        for item in data_list:
            f.write(f"{item}\n")

# %% [markdown]
# ## 1. Pano

# %%
pano_train_HNs, pano_val_HNs, pano_test_HNs = split_by_implant_image_count(pano_bone_levels_df, ratios=(0.8, 0.1, 0.1))

# %%
print(f"Train Patients: {len(pano_train_HNs)}")
print(f"Val Patients: {len(pano_val_HNs)}")
print(f"Test Patients: {len(pano_test_HNs)}\n")

print("Implants in each:")
print("Train:", pano_bone_levels_df.loc[pano_train_HNs][["level1", "level2", "level3", "level4"]].sum().sum())
print("Val:", pano_bone_levels_df.loc[pano_val_HNs][["level1", "level2", "level3", "level4"]].sum().sum())
print("Test:", pano_bone_levels_df.loc[pano_test_HNs][["level1", "level2", "level3", "level4"]].sum().sum())
# Out:
# Train Patients: 86
# Val Patients: 5
# Test Patients: 8
#
# Implants in each:
# Train: 430
# Val: 52
# Test: 56

# %%
print("Patient split for Pano---------------------------")
print_level_counts(pano_bone_levels_df, pano_train_HNs, name="Train")
print_level_counts(pano_bone_levels_df, pano_val_HNs, name="Val")
print_level_counts(pano_bone_levels_df, pano_test_HNs, name="Test")
# Out:
# Patient split for Pano---------------------------
#
# Train Split — 86 Patients
# level1    387
# level2     37
# level3      4
# level4      2
# dtype: int64
# Total implants: 430
#
# Val Split — 5 Patients
# level1    47
# level2     3
# level3     1
# level4     1
# dtype: int64
# Total implants: 52
#
# Test Split — 8 Patients
# level1    52
# level2     2
# level3     2
# level4     0
# dtype: int64
# Total implants: 56

# %% [markdown]
# the split result don't have level4 in val and test because there is only 1 patient that have level4

# %%
#save
save_list_to_txt(pano_train_HNs, "/content/pano_train.txt")
save_list_to_txt(pano_val_HNs, "/content/pano_val.txt")
save_list_to_txt(pano_test_HNs, "/content/pano_test.txt")

# %%
print(pano_train_HNs)
# Out:
# ['648550', '5318878', '599270', '5218309', '453038', '548136', '4414339', '5210908', '5420736', '5210005', '5420027', '527388', '4213295', '5420137', '5012829', '5617032', '462581', '5917597', '5110313', '4311890', '669050', '534829', '5520709', '602708', '4914618', '5118532', '574724', '4113618', '5220356', '5918305', '4813799', '505547', '544512', '4112969', '6011315', '4817019', '5211071', '4222612', '655212', '642096', '4911700', '501672', '4910683', '6114709', '67519', '5715612', '5211526', '552329', '6610915', '4113591', '4217852', '5420438', '474639', '6314082', '5114136', '521283', '5114476', '5217437', '5417742', '488619', '5219107', '521775', '5419656', '5820831', '652172', '659796', '4511244', '501440', '62199', '645485', '417543', '4817180', '623485', '5418997', '4519080', '5018823', '532924', '426836', '533497', '562468', '5419512', '611184', '5713449', '479813', '5613828', '5316510']

# %% [markdown]
# ## 2. Pano + peri

# %%
clean_bone_levels_df = bone_levels_df.reset_index()

# %%
display(clean_bone_levels_df)
# Out:
#     uniqueHN  level1  level2  level3  level4
# 0    4112969       1       1       0       0
# 1    4113591       1       1       0       0
# 2    4113618      14       0       0       0
# 3     417543       0       3       0       0
# 4    4213295       2       0       0       0
# ..       ...     ...     ...     ...     ...
# 96    655212       1       0       0       0
# 97    659796       1       0       0       0
# 98   6610915       6       1       0       0
# 99    669050       3       0       0       0
# 100    67519       2       0       0       0
#
# [101 rows x 5 columns]

# %%
def remove_rows_by_HN(bone_levels_df, HN_list):
    return bone_levels_df[~bone_levels_df['uniqueHN'].isin(HN_list)]

# %%
pano_test_hns = ["462431", "536853", "50455", "543603", "517919", "424357", "645509", "552468"]

# %%
print(len(clean_bone_levels_df))
# Out:
# 101

# %%
clean_bone_levels_df = remove_rows_by_HN(clean_bone_levels_df, pano_test_hns)

# %%
print(len(clean_bone_levels_df))
# Out:
# 93

# %%
all_train_HNs, all_val_HNs = split_by_implant_image_count_pano_peri(clean_bone_levels_df,pano_test_hns, ratios=(0.8, 0.2))
all_test_HNs = pano_test_hns

# %%
print(f"Train Patients: {len(all_train_HNs)}")
print(f"Val Patients: {len(all_val_HNs)}")

train_implants = clean_bone_levels_df[clean_bone_levels_df['uniqueHN'].isin(all_train_HNs)][["level1", "level2", "level3", "level4"]].sum().sum()
val_implants = clean_bone_levels_df[clean_bone_levels_df['uniqueHN'].isin(all_val_HNs)][["level1", "level2", "level3", "level4"]].sum().sum()

print("Implants in each:")
print("Train:", train_implants)
print("Val:", val_implants)
print("Test:", bone_levels_df.loc[all_test_HNs][["level1", "level2", "level3", "level4"]].sum().sum())
# Out:
# Train Patients: 87
# Val Patients: 5
# Implants in each:
# Train: 419
# Val: 186
# Test: 56

# %%
def print_level_counts_pano_peri(df, split_HNs, name="Set"):
    print(f"{name} Patients:", len(split_HNs))
    subset = df[df['uniqueHN'].isin(split_HNs)]
    level_sums = subset[["level1", "level2", "level3", "level4"]].sum()
    print(f"\n{name} Split — {len(split_HNs)} Patients")
    print(level_sums)
    print(f"Total implants: {level_sums.sum()}")

# %%
print("Patient split for Pano + Peri ---------------------------")
print_level_counts_pano_peri(clean_bone_levels_df, all_train_HNs, name="Train")
print_level_counts_pano_peri(clean_bone_levels_df, all_val_HNs, name="Val")
print_level_counts_pano_peri(bone_levels_df.reset_index(), all_test_HNs, name="Test")
# Out:
# Patient split for Pano + Peri ---------------------------
# Train Patients: 87
#
# Train Split — 87 Patients
# level1    371
# level2     37
# level3      8
# level4      3
# dtype: int64
# Total implants: 419
# Val Patients: 5
#
# Val Split — 5 Patients
# level1    125
# level2     22
# level3     21
# level4     18
# dtype: int64
# Total implants: 186
# Test Patients: 8
#
# Test Split — 8 Patients
# level1    52
# level2     2
# level3     2
# level4     0
# dtype: int64
# Total implants: 56

# %%
#save
save_list_to_txt(all_train_HNs, "/content/all_train.txt")
save_list_to_txt(all_val_HNs, "/content/all_val.txt")
save_list_to_txt(pano_test_hns, "/content/all_test.txt")

# %% [markdown]
# # See image count

# %%
def assign_split_labels(train_HN_list, val_HN_list, test_HN_list, datasets_df):
    df = datasets_df[["id", "Patient ID"]].copy()

    def get_split(patient_id):
        if patient_id in train_HN_list:
            return "train"
        elif patient_id in val_HN_list:
            return "val"
        elif patient_id in test_HN_list:
            return "test"
        else:
            return "unknown"  # Optional: handle IDs not in any list

    df["split"] = df["Patient ID"].apply(get_split)
    df = df.drop_duplicates(subset="id")
    return df

# %%
def assign_split_labels_pano_peri(train_HN_list, val_HN_list, datasets_df):
    df = datasets_df[["id", "Patient ID"]].copy()

    def get_split(patient_id):
        if patient_id in train_HN_list:
            return "train"
        elif patient_id in val_HN_list:
            return "val"
        else:
            return "test"  # Optional: handle IDs not in any list

    df["split"] = df["Patient ID"].apply(get_split)
    df = df.drop_duplicates(subset="id")
    return df

# %%
def print_split_ratios(split_df):
    split_counts = split_df["split"].value_counts()
    counts = split_counts.reindex(["train", "val", "test"], fill_value=0)

    train_count = counts["train"]
    val_count = counts["val"]
    test_count = counts["test"]
    total = train_count + val_count + test_count

    if total == 0:
        print("No data to compute ratios.")
        return

    train_ratio = train_count / total
    val_ratio = val_count / total
    test_ratio = test_count / total

    print(f"Train : Val : Test = {train_ratio:.2f} : {val_ratio:.2f} : {test_ratio:.2f}")

# %% [markdown]
# ## Pano

# %%
datasets_df['Patient ID'] = datasets_df['Patient ID'].str.replace("-", "", regex=False)

# %%
pano_df['Patient ID'] = pano_df['Patient ID'].str.replace("-", "", regex=False)
# Out:
# <ipython-input-69-064072f773ae>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pano_df['Patient ID'] = pano_df['Patient ID'].str.replace("-", "", regex=False)

# %%
pano_split_df = assign_split_labels(pano_train_HNs, pano_val_HNs, pano_test_HNs, pano_df)

# %%
pano_split_counts = pano_split_df["split"].value_counts()
print(pano_split_counts)
# Out:
# split
# train    157
# test      18
# val       14
# Name: count, dtype: int64

# %%
print_split_ratios(pano_split_df)
# Out:
# Train : Val : Test = 0.83 : 0.07 : 0.10

# %%
#save
pano_split_df.to_csv("/content/pano_split.csv", index=False)

# %% [markdown]
# ## Pano + Peri

# %%
all_split_df = assign_split_labels_pano_peri(all_train_HNs, all_val_HNs, datasets_df)

# %%
all_split_counts = all_split_df["split"].value_counts()
print(all_split_counts)
# Out:
# split
# train    178
# val       93
# test      64
# Name: count, dtype: int64

# %%
print_split_ratios(all_split_df)
# Out:
# Train : Val : Test = 0.53 : 0.28 : 0.19

# %%
#save
all_split_df.to_csv("/content/all_split.csv", index=False)
